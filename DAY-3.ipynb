# %% [markdown]
# ## DAY-3(Type conversion,input function,String and it's methods)

# %% [markdown]
# ### Type conversion

# %%
a="1"
b="2"
print(a+b)
print(int(a)+int(b)) ## explecit
# Out:
# 12
# 3

# %%
## inplicit casting
c=9
d=10.0
print(c+d) ## convert automatic to higher data type so no data loss
# Out:
# 19.0

# %% [markdown]
# ### input function

# %%
a=int(input("enter number 1:"))
print(a)
type(a)
# Out:
# enter number 1: 45
# 45
# int

# %% [markdown]
# ### String

# %%
name='Deep'
name
# Out:
# 'Deep'

# %%
name[0]  ## indexError
# Out:
# 'D'

# %% [markdown]
# #### String Methods

# %% [markdown]
# ## String sciling

# %%
print(name[0:5])   ## always go to left to right [5:0]->>>> not print anyhting
# Out:
# Deep

# %%
print(name[0:len(name)])
# Out:
# Deep

# %%
print(name[:len(name)])
# Out:
# Deep

# %%
print(name[0:])
# Out:
# Deep

# %%
print(name[:])
# Out:
# Deep

# %%
print(name[-2:-4]) 
print(name[-4:-2])
# Out:
# De
